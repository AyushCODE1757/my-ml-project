# %% [markdown]
# #### What are outliers?
# * The data points that are significantly different from other observations.they impact:-
#     * Mean and Standard Deviation
#      * Regression lines
#      * Model accuracy, especially in distance based algorithm(KNN, k-means)
# ---

# %% [markdown]
# #### 🔢 5 Number Summary
#
# * Min
# * Median
# * Q1
# * Q3
# * Maximum
# * IQR

# %%
lst=[14, 56, 67, 43, 56, 79, 99, 34, 23, 100, 76, 87, 34, 86, 65, 23]
import numpy as np
min,q1,median,q3,max=np.quantile(lst,[0,0.25,0.5,0.75,1.0])
iqr=q3-q1
min,q1,median,q3,max
# Out:
# (np.float64(14.0),
#  np.float64(34.0),
#  np.float64(60.5),
#  np.float64(80.75),
#  np.float64(100.0))

# %%
lower_fence=q1-(iqr*1.5)
higher_fence=q3+(iqr*1.5)

# %%
print(lower_fence)
print(higher_fence)
# Out:
# -36.125
# 150.875

# %%
import seaborn as sns
sns.boxplot(lst)
# Out:
# <Axes: >

# %%
lst=[-43.5, -37.43, 14, 56, 67, 43, 56, 79, 99, 34, 23, 100, 76, 87, 34, 86, 65, 23, 200, 240, 170]
sns.boxplot(lst)
# Out:
# <Axes: >
